# %% [markdown]
# # Python Operators
#
# In Python programming, Operators in general are used to perform operations on values and variables.
#
# Operators: Special symbols like -, + , * , /, etc.
# Operands: Value on which the operator is applied.

# %% [markdown]
# # 1.Arithmetic Operators
# Python Arithmetic operators are used to perform basic mathematical operations like addition, subtraction, multiplication and division.

# %%
a = 17
b = 5

#Addition
print(f"{a} + {b} = {a+b}")

#Substraction
print(f"{a} - {b} = {a-b}")
print(17-19)

#MUltiplication
print(f"{a} * {b} = {a*b}")

#Division
print(f"{a} / {b} = {a/b}") #Actual division

#Floor Division
print(f"{a} // {b} = {a//b}") #Gives only division with int number

#Modulos
print(f"{a} % {b} = {a%b}") #Gives only remindeerr

#Exponential
print(2**3) #Power of a
# Out:
# 17 + 5 = 22
# 17 - 5 = 12
# -2
# 17 * 5 = 85
# 17 / 5 = 3.4
# 17 // 5 = 3
# 17 % 5 = 2
# 8

# %% [markdown]
# # Comparison Operators
# In Python, Comparison (or Relational) operators compares values. It either returns True or False according to the condition.

# %%
a = 10
b = 34
print(a>b)
print(a<b)
print(10>=10)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
print(10==10)
# Out:
# False
# True
# True
# False
# True
# False
# True
# True

# %% [markdown]
# # Logical Operators
# Python Logical operators perform Logical AND, Logical OR and Logical NOT operations. It is used to combine conditional statements.
#
# The precedence of Logical Operators in Python is as follows:
# - Logical not
# - logical and
# - logical or

# %%
a = True
b = False
print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %%
# Let's try some actual program with this logic gates
# Student grade card
m1, m2, m3 = map(int, input("Enter marks of three subjects: ").split()) 
avg = (m1 + m2 + m3) / 3 
print("Total percentage:", avg)

avg = ((m1+m2+m3)/3)
print("Total percentage", avg)

if avg>=75 and avg<=100:
    print("Garde: Distincton, Well done Genius!")
elif avg>=60 and avg<75:
    print("Grade: Fisrt clas, keep learning champion!")
elif avg> 55 or avg> 35:
    print("You Passed!")
else:
    print("Garde: Fail")
# Out:
# Enter marks of three subjects:  25 5 35
# Total percentage: 21.666666666666668
# Total percentage 21.666666666666668
# Garde: Fail

# %% [markdown]
# # Bitwise Operators
# Very fast and useful while solving coding roblems
# Python Bitwise operators act on bits and perform bit-by-bit operations. These are used to operate on binary numbers.
#
# Bitwise Operators in Python are as follows:
#
#  1. Bitwise NOT
#  2. Bitwise Shift
# 3. Bitwise AND
# 4. Bitwise XOR
# 5. Bitwise OR

# %%
## while executing bitwise operator thinks in bit not in decimal
a = 10 ## binary 1010
b = 4   ##binary 0100

print(a & b)   #bitwise and : both must be 1 then 1 else 0
print(a | b)   #bitwise or: any one is 1 then 1 else 0
print(~a)      #bitwise not: flip all bits ... ~1010 → ...0101
print(a ^ b)   #bitwise xor: different bits only gives 1 else 0
print(a >> 2)  #right shift (>>) → divide by powers of 2 ,Shifts bits right, equivalent to : a // (2 ** 2)
print(a << 2)  #Left Shift (<<) → multiply by powers of 2, Shifts bits left, Equivalent to : a * (2 ** 2)
# Out:
# 0
# 14
# -11
# 14
# 2
# 40

# %% [markdown]
# | Operator    | Symbol | What it Actually Does (Bits)  | Major DSA Use Cases                                                | Typical Problems                                              |                            |
# | ----------- | ------ | ----------------------------- | ------------------------------------------------------------------ | ------------------------------------------------------------- | -------------------------- |
# | AND         | `&`    | 1 only if **both bits are 1** | • Check even/odd  <br>• Check if bit is set <br>• Power of 2 check | Bit manipulation, math, optimization                          |                            |
# | OR          | '|'      | `                             | 1 if **any bit is 1**                                              | • Set a bit <br>• Combine states/flags <br>• Bitmask creation | Subsets, state compression |
# | XOR         | `^`    | 1 if **bits are different**   | 🔥 Find unique element <br>• Toggle bits <br>• Swap numbers        | Arrays, hashing tricks                                        |                            |
# | NOT         | `~`    | Flips all bits                | • Rare in DSA <br>• Low-level bit logic                            | Advanced / system-level                                       |                            |
# | Right Shift | `>>`   | Shift right → divide by 2     | • Fast division <br>• Extract bits <br>• Binary search logic       | Bit extraction                                                |                            |
# | Left Shift  | `<<`   | Shift left → multiply by 2    | • Create bitmasks <br>• Subsets generation <br>• Fast multiply     | DP, subsets                                                   |                            |

# %% [markdown]
# # Assignment Operators
# Python Assignment operators are used to assign values to the variables. This operator is used to assign the value of the right side of the expression to the left side operand.

# %%
a = 10
b = a
print(b)
b += a
print(b)
b -= a
print(b)
b *= a
print(b)
b <<= a
print(b)
# Out:
# 10
# 20
# 10
# 100
# 102400

# %% [markdown]
# # Identity Operators
# - is        :  True if the operands are identical
# - is not    :  True if the operands are not identical

# %%
a = 10
b = 11
c = a
print(a is b)
print( a is not b)
print(a is c)
# Out:
# False
# True
# True

# %% [markdown]
# # Membership Operators
# - in        :    True if value is found in the sequence
# - not in     :    True if value is not found in the sequence

# %%
x = 24
y = 20
list = [10, 20, 30, 40, 50]

if (x not in list):
    print("x is NOT present in given list")
else:
    print("x is present in given list")

if (y in list):
    print("y is present in given list")
else:
    print("y is NOT present in given list")
# Out:
# x is NOT present in given list
# y is present in given list

# %% [markdown]
# # Ternary Operator
# It simply allows testing a condition in a single line replacing the multiline if-else, making the code compact.
# ### Syntax: [on_true] if [expression] else [on_false]

# %%
a,b = map(int, input("Number: ").split())
maximum = a if a>b else b
print("Maximum num: ", maximum)
# Out:
# Number:  25 28
# Maximum num:  28

# %% [markdown]
# #  Precedence and Associativity of Operators
# In Python, Operator precedence and associativity determine the priorities of the operator.
#
# ### Operator Precedance : BODMAS → Bitwise → Compare → == → not → and → or → assign
#
# ### Operator Associativity:  can either be Left to Right or from Right to Left.

# %%
expr = 10 + 20 * 30
print(expr)
name = "Alex"
age = 0

if name == "Alex" or name == "John" and age >= 2:
    print("Hello! Welcome.")
else:
    print("Good Bye!!")
# Out:
# 610
# Hello! Welcome.

# %%
print(100 / 10 * 10)
print(5 - 2 + 3)
print(5 - (2 + 3))
print(2 ** 3 ** 2) #Right assosiative == 2 ** (3 ** 2)
# Out:
# 100.0
# 6
# 0
# 512

# %% [markdown]
# # Associativity Table
#
# | Level | Operators               | Associativity       |              |
# | ----- | ----------------------- | ------------------- | ------------ |
# | 1     | `()` `[]` `.`           | Left → Right        |              |
# | 2     | `**`                    | **Right → Left**⚠️ |              |
# | 3     | `+x` `-x` `~x`          | Right → Left⚠️      |              |
# | 4     | `* / // %`              | Left → Right        |              |
# | 5     | `+ -`                   | Left → Right        |              |
# | 6     | `<< >>`                 | Left → Right        |              |
# | 7     | `&`                     | Left → Right        |              |
# | 8     | `^`                     | Left → Right        |              |
# | 10    | `< <= > >= == != is in` | Left → Right        |              |
# | 11    | `not`                   | Right → Left⚠️      |              |
# | 12    | `and`                   | Left → Right        |              |
# | 13    | `or`                    | Left → Right        |              |
# | 14    | `if-else` (ternary)     | Right → Left⚠️     |              |
# | 15    | `= += -= *= ...`        | **Right → Left**⚠️ |              |
