# %% [markdown]
# # Week 1 GFG Introduction to python

# %%
print("Hello World")
# Out:
# Hello World

# %%
# This is comment in python

# %%
"""
Python doesn't support multiline comment
Thus we use single or double quote
"""
# Out:
# "\nPython doesn't support multiline comment\nThus we use single or double quote\n"

# %% [markdown]
# ## Input and Output in python

# %%
x = input("Enter your name: ")          #By default evry input in python is converted into string
print(f"Hi, {x}!! Have a great day!")
# Out:
# Enter your name:  Vedika
# Hi, Vedika!! Have a great day!

# %% [markdown]
# ### Multiple Output

# %%
#We can print multiple variables by separating commas
a = 19
b = "Rani"
c = "College"

print(a,b,c)
# Out:
# 19 Rani College

# %% [markdown]
# ### Multiple Input
# We take multiple inputs in single line, by using split() method and then prints labels corresponding to input. User should give input by having space.

# %%
p, q = input("Enter two numbers: ").split()
print("First number is", p)
print("Second number is", q)
# Out:
# Enter two numbers:  12 13
# First number is 12
# Second number is 13

# %% [markdown]
# ### Change the Type of Input in Python

# %%
colour = input("What is colour of lotous?")
type(colour)
# Out:
# What is colour of lotous? Pink
# str

# %%
year = input("What is your birth year?")
type(year)
# Out:
# What is your birth year? 2005
# str

# %%
year = int(input("Birth Year?"))
type(year)
# Out:
# Birth Year? 005
# int

# %% [markdown]
# ### Python variables
# They are dynamically typed, no need to previous declaration

# %%
name = "Sanu"
age = 18
print(f"{name}: {type(name)}")
print(f"{age}: {type(age)}")
# Out:
# Sanu: <class 'str'>
# 18: <class 'int'>

# %% [markdown]
# ## Rules for Naming Variables
# To use variables effectively, we must follow Python’s naming rules:
#
# - Variable names can only contain letters, digits and underscores (_).
# - A variable name cannot start with a digit.
# - Variable names are case-sensitive like myVar and myvar are different.
# - Avoid using Python keywords like if, else, for as variable names.

# %%
#valid
age = 21
_colour = "lilac"
total_score = 90

# %%
#invalid
1name = "Error"  # Starts with a digit
class = 10       # 'class' is a reserved keyword
user-name = "Doe"  # Contains a hyphen
# Out:
#   Cell In[52], line 2
#     1name = "Error"  # Starts with a digit
#     ^
# SyntaxError: invalid decimal literal

# %%
# Multiple Assignments values

a = b = c = 1000 #same value
x, y = 65, 63 # differemt values

# %%
#swap in python
print("Before swap x and y:", x,y)
x, y = y, x
print("After swap x and y:", x,y)
# Out:
# Before swap x and y: 63 65
# After swap x and y: 65 63

# %% [markdown]
# ### Type Casting a Variable

# %%
s = "10"  
n = int(s) 
cnt = 5
f = float(cnt)  
age = 25
s2 = str(age)  

print(n)  
print(f)  
print(s2)
# Out:
# 10
# 5.0
# 25

# %%
#delete varaible with keyword
x = 10
print(x) 
del x

# Trying to print x after deletion will raise an error
# print(x)  # Uncommenting this line will raise NameError: name 'x' is not defined
# Out:
# 10

# %% [markdown]
# ### Python Keywords
# Keywords in Python are special reserved words that are part of the language itself. They define the rules and structure of Python programs which means you cannot use them as names for your variables, functions, classes or any other identifiers.

# %%
import keyword
print("List of Keywords: ")
print(keyword.kwlist)  #Total keywords in python

n = keyword.kwlist
print("\nTotal number of Keywords:", len(n))
# Out:
# List of Keywords:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
#
# Total number of Keywords: 35

# %% [markdown]
# ### Category of Keywords
# - Value Keywords: True, False, None
# - Operator Keywords: and, or, not, is, in
# - Control Flow Keywords: if, else, elif, for, while, break, continue, pass, try, except, finally, raise, assert
# - Function and Class:	def, return, lambda, yield, class
# - Context Management:	with, as
# - Import and Module:	import, from
# - Scope and Namespace:	global, nonlocal
# - Async Programming:	async, await

# %%
## GFG Task - 5
########### Write your code below ###############

# Take string input and print the string input
s = input()
print(s)
# Take integer input and add 10 to the integer input and print
n = int(input())
print(n + 10)
# Take floating-point input and multiply the float input by 10 and print
f = float(input())
print(f * 10)
########### Write your code above ###############
# Out:
#  gfg
# gfg
#  5
# 15
#  13.2
# 132.0

# %% [markdown]
# ## Multi printing

# %%
string = "Radhe - Radhe"
print(string * 10)
# Out:
# Radhe - RadheRadhe - RadheRadhe - RadheRadhe - RadheRadhe - RadheRadhe - RadheRadhe - RadheRadhe - RadheRadhe - RadheRadhe - Radhe

# %%
print("Ganapati Bappa Morya\n" * 10)
# Out:
# Ganapati Bappa Morya
# Ganapati Bappa Morya
# Ganapati Bappa Morya
# Ganapati Bappa Morya
# Ganapati Bappa Morya
# Ganapati Bappa Morya
# Ganapati Bappa Morya
# Ganapati Bappa Morya
# Ganapati Bappa Morya
# Ganapati Bappa Morya

# %% [markdown]
# - Lists always maintain insertion order. Starting from Python 3.7, dictionaries (dict) also maintain the insertion order of keys by default.
# - In Python, 0 is considered a "falsey" value, which means bool(0) evaluates to False.
